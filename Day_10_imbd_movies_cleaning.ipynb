# %% [markdown]
# Description: The dataset contains more than 120 thousands movies from 1911 to 2024, present on IMDB.
#
# Task: Clean it and do exploratory data analysis on it.Day
# Today, I am introducing you to the concept of "User Stories". It helps to guide you even more on what to do with our dataset. For the Dataset above, you are required to work according to the following user stories:
#
# 1) As a film enthusiast, I want to identify the top-rated movies across different genres, so that I can discover new high-quality films to watch.
#
# 2) Analyze Cast and Crew Relationships:
# As a movie producer, I want to identify frequently collaborating actors, directors, or writers to understand successful filmmaking teams. TIP: Develop a network visualization showcasing frequent collaborators among actors, directors, and writers.
#
# 3) As a marketing manager, I want to understand how user engagement (number of ratings) changes over time and identify genres with the most engaged audiences.
# Acceptance criteria: Generate charts illustrating the average number of ratings per year and compare it across different genres.
#
# Try these and we shall continue with more later on
#
# Good luck ladies

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

# %%
movies = pd.read_csv('/content/drive/MyDrive/Colab Notebooks gogirl/csv_files/movies_imdb.csv')

# %%
movies.shape
# Out:
# (126691, 12)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126691 entries, 0 to 126690
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Movie URL      126691 non-null  object
#  1   Title          126626 non-null  object
#  2   Poster         126384 non-null  object
#  3   Release Year   126618 non-null  float64
#  4   Length in Min  124733 non-null  float64
#  5   IMDB Rating    126624 non-null  float64
#  6   Rating Count   126624 non-null  float64
#  7   Plot           126626 non-null  object
#  8   Directors      125842 non-null  object
#  9   Writers        119634 non-null  object
#  10  Stars          125339 non-null  object
#  11  Genres         126515 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 11.6+ MB

# %%
movies.describe(include='all')
# Out:
#                                                 Movie URL   Title  \
# count                                              126691  126626
# unique                                             126691  118227
# top     https://www.imdb.com/title/tt0001892/?ref_=sr_t_3    Solo
# freq                                                    1      12
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#                                                    Poster   Release Year  \
# count                                              126384  126618.000000
# ...

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies['Title'].duplicated().sum()
# Out:
# 8463

# %%
movies[movies['Title'].duplicated()]
# Out:
#                                                 Movie URL  \
# 120     https://www.imdb.com/title/tt0007801/?ref_=sr_t_1
# 165     https://www.imdb.com/title/tt0008950/?ref_=sr_t_7
# 401     https://www.imdb.com/title/tt0013597/?ref_=sr_t_9
# 405     https://www.imdb.com/title/tt0013662/?ref_=sr_...
# 503     https://www.imdb.com/title/tt0015253/?ref_=sr_...
# ...                                                   ...
# 126666  https://www.imdb.com/title/tt2785032/?ref_=sr_...
# 126667  https://www.imdb.com/title/tt27850479/?ref_=sr...
# 126672  https://www.imdb.com/title/tt2785464/?ref_=sr_...
# 126677  https://www.imdb.com/title/tt2786278/?ref_=sr_...
# 126685  https://www.imdb.com/title/tt27873991/?ref_=sr...
#
#                             Title  \
# 120                     Cleopatra
# 165                        Carmen
# 401               Sherlock Holmes
# 405     Tess of the Storm Country
# 503                    Quo Vadis?
# ...                           ...
# ...

# %%
movies['Poster'].duplicated().sum()
# Out:
# 338

# %%
movies.isna().sum()
# Out:
# Movie URL           0
# Title              65
# Poster            307
# Release Year       73
# Length in Min    1958
# IMDB Rating        67
# Rating Count       67
# Plot               65
# Directors         849
# Writers          7057
# Stars            1352
# Genres            176
# dtype: int64

# %%
movies[movies['Title'].duplicated() & movies['Length in Min'].isna()].shape
# Out:
# (179, 12)

# %%
movies[movies['Title'].duplicated() & movies['Plot'].isna()].shape
# Out:
# (64, 12)

# %%
movies[movies['Title'].duplicated() & movies['Genres'].isna()].shape
# Out:
# (72, 12)

# %%
movies.dropna(subset=['Title'], inplace=True)

# %%
movies.isna().sum()
# Out:
# Movie URL           0
# Title               0
# Poster            242
# Release Year        8
# Length in Min    1893
# IMDB Rating         2
# Rating Count        2
# Plot                0
# Directors         784
# Writers          6992
# Stars            1287
# Genres            111
# dtype: int64

# %%
movies['Release Year'].fillna(method='ffill', inplace=True)

# %%
movies.dropna(subset= ['IMDB Rating'], inplace=True)

# %%
movies.isna().sum()
# Out:
# Movie URL           0
# Title               0
# Poster            242
# Release Year        0
# Length in Min    1893
# IMDB Rating         0
# Rating Count        0
# Plot                0
# Directors         784
# Writers          6992
# Stars            1287
# Genres            111
# dtype: int64

# %% [markdown]
# ##User story 1:  As a film enthusiast, I want to identify the top-rated movies across different genres, so that I can discover new high-quality films to watch.

# %%
# movies.groupby('Genres').sort_values('IMDB Rating', ascending=True)
# sorted_movies = movies.sort_values(['Genres', 'IMDB Rating'], ascending=[True, False])
# sorted_movies

movies.sort_values('IMDB Rating', ascending=False).groupby('Genres').head(1)
# Out:
#                                                 Movie URL  \
# 126211  https://www.imdb.com/title/tt27426876/?ref_=sr...
# 93191   https://www.imdb.com/title/tt11076052/?ref_=sr...
# 125716  https://www.imdb.com/title/tt26754306/?ref_=sr...
# 2640    https://www.imdb.com/title/tt28660608/?ref_=sr...
# 2722    https://www.imdb.com/title/tt28766081/?ref_=sr...
# ...                                                   ...
# 98977   https://www.imdb.com/title/tt12631030/?ref_=sr...
# 67317   https://www.imdb.com/title/tt0211380/?ref_=sr_...
# 13043   https://www.imdb.com/title/tt4656810/?ref_=sr_...
# 121333  https://www.imdb.com/title/tt2265116/?ref_=sr_...
# 70041   https://www.imdb.com/title/tt0256345/?ref_=sr_...
#
#                                   Title  \
# 126211                     Nannayikoode
# 93191                    Electric Burma
# 125716               Ondolle Love Story
# 2640            Ardhambardha Premakathe
# 2722                      Mukalpparappu
# ...

# %%
movies['Genres'].unique().size
# Out:
# 1408

# %% [markdown]
# ## User story 2: Analyze Cast and Crew Relationships: As a movie producer, I want to identify frequently collaborating actors, directors, or writers to understand successful filmmaking teams. TIP: Develop a network visualization showcasing frequent collaborators among actors, directors, and writers.
